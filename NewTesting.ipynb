# %%
# !pip install yahoo-fin
# Out:
# Requirement already satisfied: yahoo-fin in c:\users\sridhar\miniconda3\lib\site-packages (0.8.9.1)
# Requirement already satisfied: requests-html in c:\users\sridhar\miniconda3\lib\site-packages (from yahoo-fin) (0.10.0)
# Requirement already satisfied: pandas in c:\users\sridhar\miniconda3\lib\site-packages (from yahoo-fin) (1.1.0)
# Requirement already satisfied: feedparser in c:\users\sridhar\miniconda3\lib\site-packages (from yahoo-fin) (6.0.8)
# Requirement already satisfied: requests in c:\users\sridhar\miniconda3\lib\site-packages (from yahoo-fin) (2.23.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in c:\users\sridhar\miniconda3\lib\site-packages (from requests-html->yahoo-fin) (0.2.6)
# Requirement already satisfied: pyquery in c:\users\sridhar\miniconda3\lib\site-packages (from requests-html->yahoo-fin) (1.4.3)
# Requirement already satisfied: fake-useragent in c:\users\sridhar\miniconda3\lib\site-packages (from requests-html->yahoo-fin) (0.1.11)
# Requirement already satisfied: w3lib in c:\users\sridhar\miniconda3\lib\site-packages (from requests-html->yahoo-fin) (1.22.0)
# Requirement already satisfied: bs4 in c:\users\sridhar\miniconda3\lib\site-packages (from requests-html->yahoo-fin) (0.0.1)
# Requirement already satisfied: parse in c:\users\sridhar\miniconda3\lib\site-packages (from requests-html->yahoo-fin) (1.19.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\sridhar\miniconda3\lib\site-packages (from pandas->yahoo-fin) (2020.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\sridhar\miniconda3\lib\site-packages (from pandas->yahoo-fin) (1.19.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\sridhar\miniconda3\lib\site-packages (from pandas->yahoo-fin) (2.8.1)
# Requirement already satisfied: sgmllib3k in c:\users\sridhar\miniconda3\lib\site-packages (from feedparser->yahoo-fin) (1.0.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\sridhar\miniconda3\lib\site-packages (from requests->yahoo-fin) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sridhar\miniconda3\lib\site-packages (from requests->yahoo-fin) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\sridhar\miniconda3\lib\site-packages (from requests->yahoo-fin) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sridhar\miniconda3\lib\site-packages (from requests->yahoo-fin) (2020.6.20)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\sridhar\miniconda3\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo-fin) (4.46.0)
# Requirement already satisfied: websockets<10.0,>=9.1 in c:\users\sridhar\miniconda3\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo-fin) (9.1)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\sridhar\miniconda3\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo-fin) (1.7.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\sridhar\miniconda3\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo-fin) (1.4.4)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in c:\users\sridhar\miniconda3\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo-fin) (8.2.2)
# Requirement already satisfied: lxml>=2.1 in c:\users\sridhar\miniconda3\lib\site-packages (from pyquery->requests-html->yahoo-fin) (4.6.3)
# Requirement already satisfied: cssselect>0.7.9 in c:\users\sridhar\miniconda3\lib\site-packages (from pyquery->requests-html->yahoo-fin) (1.1.0)
# Requirement already satisfied: six>=1.4.1 in c:\users\sridhar\miniconda3\lib\site-packages (from w3lib->requests-html->yahoo-fin) (1.14.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\sridhar\miniconda3\lib\site-packages (from bs4->requests-html->yahoo-fin) (4.10.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\sridhar\miniconda3\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo-fin) (3.1.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sridhar\miniconda3\lib\site-packages (from beautifulsoup4->bs4->requests-html->yahoo-fin) (2.2.1)

# %%
import yahoo_fin.stock_info as yf
import pandas as pd
import time

# %%
balance_sheet = []
income_statement = []
cfs = []
years = []
profitability_score = 0
leverage_score = 0
operating_efficiency_score = 0
pe_ratio = 0

summary = pd.DataFrame(columns = ['Ticker', 'Year', 'ROE',
                                  'ROA', 'ROFL',
                                  'Profit Margin', 'Asset Turnover', 
                                 'APT', 'ART', 'INVT', 'PPET', 'C2C', 'S&GA/Revenue'])

tickers = yf.tickers_sp500()

# %%
def get_data(ticker):
    global balance_sheet
    global income_statement
    global cfs
    global years
    balance_sheet = yf.get_balance_sheet(ticker)
    income_statement = yf.get_income_statement(ticker)
    cfs = yf.get_cash_flow(ticker)
    years = balance_sheet.columns

# %%
def get_calcs():
    
    global ROA, ROE, ROFL, Profit_Margin, Asset_Turnover, APT, ART, INVT, PPET, C2C, SGR
    global ROA_py, ROE_py, ROFL_py, Profit_Margin_py, Asset_Turnover_py, APT_py, ART_py, INVT_py, PPET_py, C2C_py, SGR_py    
    
    netIncome = income_statement[years[0]]['netIncome']
    netIncome_py = income_statement[years[1]]['netIncome']
    
    totalAssets = balance_sheet[years[0]]['totalAssets']
    totalAssets_py = balance_sheet[years[1]]['totalAssets']
    
    interestExpense = income_statement[years[0]]['interestExpense']       
    interestExpense_py = income_statement[years[1]]['interestExpense']  
    
    totalShareholderEquity = balance_sheet[years[0]]['totalStockholderEquity']
    totalShareholderEquity_py = balance_sheet[years[1]]['totalStockholderEquity']
    
    totalRevenue = income_statement[years[0]]['totalRevenue']
    totalRevenue_py = income_statement[years[1]]['totalRevenue']
    
    cogs = income_statement[years[0]]['totalRevenue'] - income_statement[years[0]]['grossProfit']
    cogs_py = income_statement[years[1]]['totalRevenue'] - income_statement[years[1]]['grossProfit']
    
    netReceivables = balance_sheet[years[0]]['netReceivables']
    netReceivables_py = balance_sheet[years[1]]['netReceivables']
    
    inventory = balance_sheet[years[0]]['inventory']
    inventory_py = balance_sheet[years[1]]['inventory']

    pPE  = balance_sheet[years[0]]['propertyPlantEquipment']
    pPE_py  = balance_sheet[years[1]]['propertyPlantEquipment']
    
    sga = income_statement[years[0]]['sellingGeneralAdministrative']
    sga_py = income_statement[years[1]]['sellingGeneralAdministrative']
    
    accountsPayable = balance_sheet[years[0]]['accountsPayable']
    accountsPayable_py = balance_sheet[years[1]]['accountsPayable']
    
 
    ROE = netIncome/totalShareholderEquity
    
    ROA = (netIncome + (1-0.35)*interestExpense )/totalAssets
    
    ROFL = ROE - ROA
    
  
    Profit_Margin = (netIncome + (1-0.35)*interestExpense )/totalRevenue
    
    Asset_Turnover = totalRevenue/totalAssets
    
    APT = cogs/accountsPayable
    
    ART = totalRevenue/netReceivables
    
    INVT = cogs/inventory
    
    PPET = totalRevenue/pPE
    
    C2C = -1.0/APT + 1.0/ART + 1.0/INVT
    
    SGR = sga/totalRevenue
    
    ROE_py = netIncome_py/totalShareholderEquity_py
    
        
    ROA_py = (netIncome_py + (1-0.35)*interestExpense_py )/totalAssets_py
    
    ROFL_py = ROE_py - ROA_py
    
    Profit_Margin_py = (netIncome_py + (1-0.35)*interestExpense_py )/totalRevenue_py
    
    Asset_Turnover_py = totalRevenue_py/totalAssets_py
    
    APT_py = cogs_py/accountsPayable_py
    
    ART_py = totalRevenue_py/netReceivables_py
    
    INVT_py = cogs_py/inventory_py
    
    PPET_py = totalRevenue_py/pPE_py
    
    C2C_py = -1.0/APT_py + 1.0/ART_py + 1.0/INVT_py
    
    SGR_py = sga_py/totalRevenue_py

# %%
for ticker in tickers[4:6]:
    try:
        get_data(ticker)
        get_calcs()
       
        new_row = {'Ticker': ticker,'Year': years[0], 
                   'ROE': ROE,
                   'ROA': ROA, 'ROFL': ROFL,
                   'Profit Margin': Profit_Margin, 'Asset Turnover': Asset_Turnover, 
                   'APT':APT, 'ART':ART, 'INVT':INVT, 'PPET':PPET, 'C2C':C2C, 'S&GA/Revenue':SGR}

        summary = summary.append(new_row, ignore_index = True)
        new_row = {'Ticker': ticker,'Year': years[1], 
                   'ROE': ROE_py,
                   'ROA': ROA_py, 'ROFL': ROFL_py,
                   'Profit Margin': Profit_Margin_py, 'Asset Turnover': Asset_Turnover_py, 
                   'APT':APT_py, 'ART':ART_py, 'INVT':INVT_py, 'PPET':PPET_py, 'C2C':C2C_py, 'S&GA/Revenue':SGR_py}

        summary = summary.append(new_row, ignore_index = True)
        print(ticker + ' added.')
        time.sleep(3)
    except:
        print(ticker + ': Something went wrong.')

summary.to_csv('Summary.csv')
# Out:
# ABBV added.
# ABC added.

# %%
summary
# Out:
#   Ticker       Year       ROE       ROA      ROFL  Profit Margin  \
# 0    ATO 2020-09-30  0.088562  0.035584  0.052978       0.193729
# 1    ATO 2020-09-30  0.088562  0.035584  0.052978       0.193729
# 2    ATO 2019-09-30  0.088937  0.033241  0.055695       0.153129
# 3    ATO 2020-09-30  0.088562  0.035584  0.052978       0.193729
# 4    ATO 2019-09-30  0.088937  0.033241  0.055695       0.153129
# 5   ABBV 2020-12-31  0.353013  0.020064  0.332949       0.065953
# 6   ABBV 2019-12-31 -0.964513  0.075435 -1.039948       0.202080
# 7    ABC 2020-09-30  3.345408 -0.079317  3.424725      -0.018493
# 8    ABC 2019-09-30  0.297113  0.018593  0.278521       0.004055
#
#    Asset Turnover       APT        ART       INVT        PPET       C2C  \
# 0        0.183679  7.035778  12.234164  10.847498    0.207704  0.031795
# 1        0.183679  7.035778  12.234164  10.847498    0.207704  0.031795
# 2        0.217080  6.978252  12.585486  10.945250    0.246177  0.027518
# 3        0.183679  7.035778  12.234164  10.847498    0.207704  0.031795
# 4        0.217080  6.978252  12.585486  10.945250    0.246177  0.027518
# 5        0.304214  6.176186   5.192020   4.246828    7.456292  0.266161
# 6        0.373293  5.123278   6.128592   4.103144   10.062311  0.211698
# 7        4.288981  5.825749  13.247124  14.671667   98.475845 -0.028005
# 8        4.584632  6.151003  14.491480  15.785956  101.433210 -0.030222
#
#    S&GA/Revenue
# 0      0.001130
# 1      0.001130
# 2     -0.001039
# 3      0.001130
# 4     -0.001039
# 5      0.215418
# 6      0.203301
# 7      0.014373
# 8      0.014831
